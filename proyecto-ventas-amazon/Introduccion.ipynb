# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-teammexcol/blob/main/proyecto-ventas-amazon/Introduccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto

# %% [markdown]
# ## Importando dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# ### Iniciando

# %%
df = pd.read_csv('abs083122 - clear.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1450 non-null   int64
#  1   product_name  1448 non-null   object
#  2   category      1450 non-null   object
#  3   categoryRank  1448 non-null   object
#  4   noRatings     1450 non-null   object
#  5   cost          1450 non-null   object
#  6   REVIEWLIST    1450 non-null   object
#  7   product_url   1448 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 90.8+ KB

# %%
df.head(20)
# Out:
#     Unnamed: 0                                       product_name  \
# 0            0  Fire TV Stick with Alexa Voice Remote (include...
# 1            1  Fire TV Stick 4K Max streaming device, Wi-Fi 6...
# 2            2  Blink Mini – Compact indoor plug-in smart secu...
# 3            3               Introducing Blink Video Doorbell - P
# 4            4  All-new Ring Video Doorbell (2nd Gen) – 1080p ...
# 5            5  Echo Show 5 (2nd Gen, 2021 release) | Smart di...
# 6            6  Echo Dot (3rd Gen, 2018 release) - Smart speak...
# 7            7  Echo Dot (4th Gen, 2020 release) | Smart speak...
# 8            8                                  Amazon Smart Plug
# 9            9  All-new Echo Dot (4th Gen) | Smart speaker wit...
# 10          10  Fire TV Stick Lite with latest Alexa Voice Rem...
# 11          11  Kindle Paperwhite (8 GB) – Now with a 6.8" dis...
# 12          12  All-new Ring Stick Up Cam HD security camera w...
# ...

# %%
df['REVIEWLIST']
# Out:
# 0       [{'review_meta': 'Reviewed in the United State...
# 1       [{'review_meta': 'Reviewed in the United State...
# 2       [{'review_meta': 'Reviewed in the United State...
# 3       [{'review_meta': 'Reviewed in the United State...
# 4       [{'review_meta': 'Reviewed in the United State...
#                               ...
# 1445    [{'review_meta': 'Reviewed in the United State...
# 1446                                                   []
# 1447    [{'review_meta': 'Reviewed in the United State...
# 1448    [{'review_meta': 'Reviewed in the United State...
# 1449    [{'review_meta': 'Reviewed in the United State...
# Name: REVIEWLIST, Length: 1450, dtype: object
